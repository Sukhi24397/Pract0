# %%
#Sukhi
#25070123112
print("sukhi gowda")
# Out:
# sukhi gowda

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
print("sukhi gowda")
print(2)
print([1,2,5])
# Out:
# sukhi gowda
# 2
# [1, 2, 5]

# %%
x=2
y=[1,2,5]
z="sukhi gowda"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# sukhi gowda
