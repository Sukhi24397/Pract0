# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukhi24397/Pract0/blob/main/Experiment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Sukhi N
#25070123112
#Study of set in python

# %%
thisset={"apple","banana","cherry"}
print(thisset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
thisset={"apple","banana","cherry",}
print(thisset[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3793203917.py in <cell line: 0>()
#       1 thisset={"apple","banana","cherry",}
# ----> 2 print(thisset[1])
#
# TypeError: 'set' object is not subscriptable

# %%
thisset={"apple","banana","cherry","apple"}
print(thisset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
thisset={"apple","banana","cherry",True,1,2}
print(thisset)
# Out:
# {'banana', True, 2, 'apple', 'cherry'}

# %%
thisset={"apple","banana","cherry","apple"}
print("banana" in thisset)
print("Grapes" in thisset)
# Out:
# True
# False

# %%
thisset={"apple","banana","cherry"}
thisset.add("orange")
print(thisset)
# Out:
# {'banana', 'apple', 'cherry', 'orange'}

# %%
thisset={"apple","banana","cherry"}
thisset.add(2)
print(thisset)
# Out:
# {'banana', 'apple', 'cherry', 2}

# %%
thisset={"apple","banana","cherry"}
thisset.remove("banana")
print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
# Set Operation
A={1,2,3,4}
B={3,4,5,6}

print("union:", A|B)
print("intersection:", A&B)
print("Difference1:", A-B)
print("Difference2:", B-A)
print("symmetric difference:", A^B)
# Out:
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}
# Difference1: {1, 2}
# Difference2: {5, 6}
# symmetric difference: {1, 2, 5, 6}

# %%
# Frozenset
x=frozenset({"apple","banana","cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'banana', 'apple', 'cherry'})
# <class 'frozenset'>

# %%
studentlist={"a","b","c","d","b","c"}
studentlist=set(studentlist)
y=studentlist
print(y)
# Out:
# {'c', 'a', 'd', 'b'}

# %%
x={"Maths","Physics","Chemistry"}
y={"Biology","Physics","Chemistry"}
z= {"Maths","Biology","Chemistry"}
common_subjects=x & y & z
print(common_subjects)
# Out:
# {'Chemistry'}

# %%
cricket={"Vishvam","Yogesh","sukhi"}
football={"Vishvam","Glen","Vrishin"}
print("students in one club are", cricket & football)
print("students in one club are",cricket^football)
# Out:
# students in one club are {'Vishvam'}
# students in one club are {'Vrishin', 'Glen', 'Yogesh', 'sukhi'}

# %%
all_students={"Vishvam","Khushi","Harshita","Kshitij","Niyant","sukhi"}
present_students={"Vishvam","Khushi","sukhi" }

absent_students= all_students-present_students

print("Absent students", absent_students)
# Out:
# Absent students {'Niyant', 'Harshita', 'Kshitij'}

# %%
course={"ETC101", "ETC102", "ETC103"}
course.discard("ETC102")
print("Updated Course", course)
# Out:
# Updated Course {'ETC101', 'ETC103'}
