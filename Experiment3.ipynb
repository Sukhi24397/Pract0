# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukhi24397/Pract0/blob/main/Experiment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Sukhi N
#25070123112
#Exp3: Study of Tupple in Python

# %%
tpl=(2,"Sukhi",True)
print(tpl)
# Out:
# (2, 'Sukhi', True)

# %%
tpl1=("apple","banana","orange")
print(tpl1)
# Out:
# ('apple', 'banana', 'orange')

# %%
tpl1=("apple","banana","orange")
tpl1[1]="kiwi"
print(tpl1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2462753347.py in <cell line: 0>()
#       1 tpl1=("apple","banana","orange")
# ----> 2 tpl1[1]="kiwi"
#       3 print(tpl1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
tpl3=(10,)*5
print(tpl3)
# Out:
# (10, 10, 10, 10, 10)

# %%
tpl4=(10)*5
print(tpl4)
# Out:
# 50

# %%
list=["symbiosis",]*5
print(list)
# Out:
# ['symbiosis', 'symbiosis', 'symbiosis', 'symbiosis', 'symbiosis']

# %%
tpl4=("apple","banana","orange")
print("before:",id(tpl4))
tpl5=("mango",)
tpl4+=tpl5
print(tpl4)
print("after:",id(tpl4))
# Out:
# before: 139701079742272
# ('apple', 'banana', 'orange', 'mango')
# after: 139701078424480

# %%
tpl4=["apple","banana","orange"]
print("before:",id(tpl4))
tpl5=["mango",]
tpl4+=tpl5
print(tpl4)
print("after:",id(tpl4))
# Out:
# before: 139701080445824
# ['apple', 'banana', 'orange', 'mango']
# after: 139701080445824

# %%
marks=(78,85,90,66,88)
print(max(marks))
print(min(marks))
print(sum(marks))
print(len(marks))
print(sum(marks)/len(marks))
print(sorted(marks))
# Out:
# 90
# 66
# 407
# 5
# 81.4
# [66, 78, 85, 88, 90]

# %%
#result analysis
result=("maths",82,"A")

#unpack the tuple
subject,marks,grade=result

subject,marks,grade=result

#display the result details
print("subject:",subject)
print("marks:",marks)
print("grade:",grade)

#check for distinction
if marks>=75:
    print("Distinction")
# Out:
# subject: maths
# marks: 82
# grade: A
# Distinction

# %%
#Monitoring attendance
attendance=["P","A","P","P","A","P"]
print("total present days:",attendance.count("P"))
print("total absent days:",attendance.count("A"))
if "A" in attendance:
    print("employee was absent at least once")
# Out:
# total present days: 4
# total absent days: 2
# employee was absent at least once
