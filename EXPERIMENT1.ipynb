# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukhi24397/Pract0/blob/main/EXPERIMENT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exp1:INTRODUCTION TO PYTHON
# #SUKHI N
# #25070123112

# %%
x,y,z="apple","cherry","orange"
print(x,y,z,sep="\n")
# Out:
# apple
# cherry
# orange

# %%
x,y,w,z =2,2.5,"sukhi",True
print(type(x),type(y),type(w),type(z),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=10,5
print("sum=",a+b,"\n")
print("sub=",a-b,"\n")
print("mult=",a*b,"\n")
print("div=",a/b,"\n")
print("exp=",a**b,"\n")
# Out:
# sum= 15
#
# sub= 5
#
# mult= 50
#
# div= 2.0
#
# exp= 100000

# %%
a,b=10,5
print("sum=",a+b,"\n")
print("sub=",a-b,"\n")
print("mult=",a*b,"\n")
print("div=",a/b,"\n")
print("exp=",a**b,"\n")

# %%
a=int(input("enter the value of a="))
b=int(input("enter the value of b="))
print("sum=",a+b,"\n","sub=",a-b,"\n","mult=",a*b,"\n","div=",a/b,"\n","exp=",a**b,"\n")
# Out:
# enter the value of a=12
# enter the value of b=21
# sum= 33
#  sub= -9
#  mult= 252
#  div= 0.5714285714285714
#  exp= 46005119909369701466112

# %%
import math
x=input("enter radius=")
print("area=",math.pi*float(x)**2)
# Out:
# enter radius=25
# area= 1963.4954084936207

# %%
import math
print(math.log10(10))
# Out:
# 1.0

# %%
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
if a>b:
  print("a greater than b")
elif b>a:
  print("b greater than a")
else:
  print("both are equal")
# Out:
# Enter First Number: 6
# Enter Second Number: 6
# both are equal
