# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukhi24397/Pract0/blob/main/Experiment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Sukhi N
#25070123112
#Exp2:study of list in python
list1=["apple","orange","cherry"]
print(list1)
# Out:
# ['apple', 'orange', 'cherry']

# %%
list2=[2,2.5,'apple',True]
print(list2)
# Out:
# [2, 2.5, 'apple', True]

# %%
list3=["apple","banana","orange","cherry","kiwi","mango"]
print(list3[3])
print(list3[-3])
print(list3[2:5])
print(list3[:4])
print(list3[2:])
print(list3[-4:-1])
print(len(list3))
# Out:
# cherry
# cherry
# ['orange', 'cherry', 'kiwi']
# ['apple', 'banana', 'orange', 'cherry']
# ['orange', 'cherry', 'kiwi', 'mango']
# ['orange', 'cherry', 'kiwi']
# 6

# %%
list4=["apple","orange","cherry"]
list4[1]="mango"
print(list4)
# Out:
# ['apple', 'mango', 'cherry']

# %%
list5=["apple","orange","cherry"]
list5.append("mango")
print(list5)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list6=["apple","orange","cherry"]
list6.insert(1,"mango")
print(list6)
# Out:
# ['apple', 'mango', 'orange', 'cherry']

# %%
list7=["apple","banana","orange"]
list8=["kiwi","mango","cherry"]
list7.extend(list8)
print(list7)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'mango', 'cherry']

# %%
marks=[78,85,90,66,88]
print(max(marks))
print(min(marks))
print(sum(marks))
print(len(marks))
print(sum(marks)/len(marks))
# Out:
# 90
# 66
# 407
# 5
# 81.4

# %%
#grocery list
grocery=["milk","flour","butter","rice flour","sugar"]
print(grocery)
# Out:
# ['milk', 'flour', 'butter', 'rice flour', 'sugar']

# %%
grocery.insert(1,"peanuts")
print(grocery)
# Out:
# ['milk', 'peanuts', 'flour', 'butter', 'rice flour', 'sugar']

# %%
grocery.remove
print(grocery)
# Out:
# ['milk', 'peanuts', 'flour', 'butter', 'rice flour', 'sugar']

# %%
grocery.append("cake")
print(grocery)
# Out:
# ['milk', 'peanuts', 'flour', 'butter', 'rice flour', 'sugar', 'cake']
